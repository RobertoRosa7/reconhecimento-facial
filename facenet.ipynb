# %%
import cv2
import matplotlib.pyplot as plt

# %%
imagem = cv2.imread("../databases/pictures/px-girl.jpg")
plt.imshow(imagem)

# %%
imagem.shape
# Out:
# (853, 1280, 3)

# %%
imagem_rgb = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)
plt.imshow(imagem_rgb)

# %%
imagem_rgb.shape
# Out:
# (853, 1280, 3)

# %%
imagem_gray = cv2.cvtColor(imagem_rgb, cv2.COLOR_RGB2GRAY)
plt.imshow(imagem_gray, cmap="gray")

# %%
imagem_gray.shape
# Out:
# (853, 1280)

# %%
imagem = cv2.imread("../databases/pictures/px-people.jpg")
imagem = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)
plt.imshow(imagem)

# %%
imagem.shape
# Out:
# (853, 1280, 3)

# %%
imagem_roi = imagem[100:200, 1000:1200]
plt.imshow(imagem_roi)

# %%
imagem_roi_bgr = cv2.cvtColor(imagem_roi, cv2.COLOR_RGB2BGR)
cv2.imwrite("../databases/pictures/image_roi.png", imagem_roi_bgr)
# Out:
# True
